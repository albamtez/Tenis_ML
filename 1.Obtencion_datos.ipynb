# %% [markdown]
# <font size="7"><span style="color: #33D6CC;">OBTENCIÓN DE DATOS</span></font>

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# **Datos derivados de Jeff Sackmann's Tennis databases**
#
# **Licencia original: CC BY-NC-SA 4.0**
#
# **Fuente: https://github.com/JeffSackmann/tennis_atp**

# %%
lista_csv=[]
    # Recorrer csv's
for i in range(1968,2025): 
    ruta = f'atp_matches_{i}.csv'
    lista_csv.append(ruta)

    # Crear una lista vacía para almacenar los DataFrames de cada archivo CSV
lista_df = []

    # Leer cada archivo CSV y añadirlo a la lista
for archivo in lista_csv:
     df = pd.read_csv(archivo)
     lista_df.append(df)

    # Concatenar todos los DataFrames en uno solo
df = pd.concat(lista_df, ignore_index=True)
df
# Out:
#                               tourney_id                  tourney_name  \
# 0                              1968-2029                        Dublin
# 1                              1968-2029                        Dublin
# 2                              1968-2029                        Dublin
# 3                              1968-2029                        Dublin
# 4                              1968-2029                        Dublin
# ...                                  ...                           ...
# 193332  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA
# 193333  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA
# 193334  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA
# 193335  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA
# 193336  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA
#
#        surface  draw_size tourney_level  tourney_date  match_num  winner_id  \
# ...

# %%
df.isnull().mean()*100
# Out:
# tourney_id             0.000000
# tourney_name           0.000000
# surface                1.546522
# draw_size              0.431888
# tourney_level          0.000000
# tourney_date           0.000000
# match_num              0.000000
# winner_id              0.000000
# winner_seed           62.995185
# winner_entry          91.236546
# winner_name            0.000000
# winner_hand            0.005172
# winner_ht              8.845177
# winner_ioc             0.004138
# winner_age             0.678091
# loser_id               0.000000
# loser_seed            81.133461
# loser_entry           85.141489
# loser_name             0.000000
# loser_hand             0.025344
# loser_ht              15.468327
# loser_ioc              0.037241
# loser_age              2.408747
# score                  0.004655
# best_of                0.000000
# round                  0.000000
# minutes               51.544712
# w_ace                 50.116636
# w_df                  50.117153
# ...

# %%
    #guardamos el df bruto en un csv
df.to_csv('tenis_bruto.csv',index=False)
